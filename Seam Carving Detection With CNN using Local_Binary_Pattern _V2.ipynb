# %% [markdown]
# ## Seam Carving Detection With CNN + Local_Binary_Pattern _V2

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from keras import layers
from keras import models
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = './30000_lbp/train'
validation_dir = './30000_lbp/validation'

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), strides=(1, 1), padding='same', input_shape=(500, 500, 3)))
model.add(layers.Activation('relu')) # this is just different syntax for specifying the activation function
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
#padding='valid'
model.add(layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

model.add(layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

model.add(layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))


model.add(layers.Conv2D(256, (3, 3), strides=(1, 1), padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))


model.add(layers.Flatten())
model.add(layers.Dropout(0.1))
model.add(layers.Dense(512))
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(4, activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer=optimizers.RMSprop(lr=1e-4),metrics=['acc'])#RMSprop(lr=1e-4)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\HamidullahTurkmen\.conda\envs\DeepLearning\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\HamidullahTurkmen\.conda\envs\DeepLearning\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 500, 500, 32)      896
# _________________________________________________________________
# activation_1 (Activation)    (None, 500, 500, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 250, 250, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 250, 250, 64)      18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 250, 250, 64)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 125, 125, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 125, 125, 64)      36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 125, 125, 64)      0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 62, 62, 128)       73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 62, 62, 128)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 31, 31, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 31, 31, 256)       295168
# _________________________________________________________________
# activation_5 (Activation)    (None, 31, 31, 256)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 57600)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 57600)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               29491712
# _________________________________________________________________
# activation_6 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 29,919,108
# Trainable params: 29,919,108
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_dir,
        # All images will be resized to 150x150
        target_size=(500, 500),
        #No. of images to be yielded from the generator per batch.
        batch_size=5,
        # Since we use binary_crossentropy loss, 
        #we need binary labels
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(500, 500),
        batch_size=5,
        class_mode='categorical')
# Out:
# Found 120000 images belonging to 4 classes.
# Found 40000 images belonging to 4 classes.

# %%
for data_batch, labels_batch in train_generator:
    print('data batch shape:', data_batch.shape)
    print('labels batch shape:', labels_batch.shape)
    break
# Out:
# data batch shape: (5, 500, 500, 3)
# labels batch shape: (5, 4)

# %%
import matplotlib.pyplot as plt
for data_batch, labels_batch in train_generator:
    print('data batch shape:', data_batch.shape)
    print('labels batch shape:', labels_batch.shape)
    plt.imshow(data_batch[0,:,:,:])       
    break
# Out:
# data batch shape: (5, 500, 500, 3)
# labels batch shape: (5, 4)

# %%
history = model.fit_generator(
      train_generator,
      steps_per_epoch=500,
      epochs=70,
      validation_data=validation_generator,
      validation_steps=200)
# Out:
# WARNING:tensorflow:From C:\Users\HamidullahTurkmen\.conda\envs\DeepLearning\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/70
# 500/500 [==============================] - 67s 135ms/step - loss: 1.3981 - acc: 0.2472 - val_loss: 1.3889 - val_acc: 0.2410
# Epoch 2/70
# 500/500 [==============================] - 63s 127ms/step - loss: 1.3898 - acc: 0.2504 - val_loss: 1.3857 - val_acc: 0.2550
# Epoch 3/70
# 500/500 [==============================] - 63s 127ms/step - loss: 1.3634 - acc: 0.3068 - val_loss: 1.2285 - val_acc: 0.4140
# Epoch 4/70
# 500/500 [==============================] - 63s 127ms/step - loss: 1.0492 - acc: 0.5260 - val_loss: 0.7645 - val_acc: 0.6560
# Epoch 5/70
# 500/500 [==============================] - 63s 127ms/step - loss: 0.6071 - acc: 0.7756 - val_loss: 0.4782 - val_acc: 0.8210
# Epoch 6/70
# 500/500 [==============================] - 63s 127ms/step - loss: 0.4636 - acc: 0.8264 - val_loss: 0.4632 - val_acc: 0.8210
# Epoch 7/70
# 500/500 [==============================] - 63s 127ms/step - loss: 0.4681 - acc: 0.8196 - val_loss: 0.5753 - val_acc: 0.7880
# Epoch 8/70
# 500/500 [==============================] - 63s 127ms/step - loss: 0.4306 - acc: 0.8384 - val_loss: 0.3716 - val_acc: 0.8390
# Epoch 9/70
# 500/500 [==============================] - 63s 127ms/step - loss: 0.3952 - acc: 0.8428 - val_loss: 0.3638 - val_acc: 0.8690
# Epoch 10/70
# 500/500 [==============================] - 63s 127ms/step - loss: 0.3892 - acc: 0.8504 - val_loss: 0.3695 - val_acc: 0.8640
# Epoch 11/70
# 500/500 [==============================] - 63s 127ms/step - loss: 0.3896 - acc: 0.8500 - val_loss: 0.3995 - val_acc: 0.8390
# Epoch 12/70
# 500/500 [==============================] - 63s 127ms/step - loss: 0.4014 - acc: 0.8508 - val_loss: 0.3881 - val_acc: 0.8320
# Epoch 13/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.4062 - acc: 0.8420 - val_loss: 0.3033 - val_acc: 0.8780
# Epoch 14/70
# 500/500 [==============================] - 63s 127ms/step - loss: 0.3906 - acc: 0.8416 - val_loss: 0.3646 - val_acc: 0.8410
# Epoch 15/70
# 500/500 [==============================] - 63s 127ms/step - loss: 0.3784 - acc: 0.8572 - val_loss: 0.3400 - val_acc: 0.8740
# Epoch 16/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3694 - acc: 0.8620 - val_loss: 0.3860 - val_acc: 0.8530
# Epoch 17/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3650 - acc: 0.8692 - val_loss: 0.2923 - val_acc: 0.8680
# Epoch 18/70
# 500/500 [==============================] - 63s 127ms/step - loss: 0.3747 - acc: 0.8596 - val_loss: 0.3209 - val_acc: 0.8750
# Epoch 19/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3791 - acc: 0.8544 - val_loss: 0.4038 - val_acc: 0.8420
# Epoch 20/70
# 500/500 [==============================] - 63s 127ms/step - loss: 0.4024 - acc: 0.8524 - val_loss: 0.3546 - val_acc: 0.8650
# Epoch 21/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3657 - acc: 0.8740 - val_loss: 0.3139 - val_acc: 0.8750
# Epoch 22/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3297 - acc: 0.8672 - val_loss: 0.4056 - val_acc: 0.8400
# Epoch 23/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3821 - acc: 0.8608 - val_loss: 0.3996 - val_acc: 0.8720
# Epoch 24/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3929 - acc: 0.8624 - val_loss: 0.3731 - val_acc: 0.8530
# Epoch 25/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3649 - acc: 0.8676 - val_loss: 0.3350 - val_acc: 0.8720
# Epoch 26/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3501 - acc: 0.8724 - val_loss: 0.3569 - val_acc: 0.8710
# Epoch 27/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3241 - acc: 0.8720 - val_loss: 0.4197 - val_acc: 0.8530
# Epoch 28/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3831 - acc: 0.8616 - val_loss: 0.3330 - val_acc: 0.8780
# Epoch 29/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.4010 - acc: 0.8520 - val_loss: 0.4104 - val_acc: 0.8360
# Epoch 30/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3750 - acc: 0.8792 - val_loss: 0.3574 - val_acc: 0.8680
# Epoch 31/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3789 - acc: 0.8616 - val_loss: 0.3124 - val_acc: 0.8790
# Epoch 32/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.4047 - acc: 0.8632 - val_loss: 0.4410 - val_acc: 0.8780
# Epoch 33/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3566 - acc: 0.8608 - val_loss: 0.3195 - val_acc: 0.8730
# Epoch 34/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3839 - acc: 0.8660 - val_loss: 0.3820 - val_acc: 0.8510
# Epoch 35/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3725 - acc: 0.8576 - val_loss: 0.3892 - val_acc: 0.8660
# Epoch 36/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3609 - acc: 0.8664 - val_loss: 0.4166 - val_acc: 0.8790
# Epoch 37/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3752 - acc: 0.8692 - val_loss: 0.3272 - val_acc: 0.8790
# Epoch 38/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.4001 - acc: 0.8656 - val_loss: 0.3165 - val_acc: 0.8810
# Epoch 39/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.4098 - acc: 0.8608 - val_loss: 0.3394 - val_acc: 0.8780
# Epoch 40/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3571 - acc: 0.8736 - val_loss: 0.3546 - val_acc: 0.8720
# Epoch 41/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3844 - acc: 0.8572 - val_loss: 0.3366 - val_acc: 0.8660
# Epoch 42/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3953 - acc: 0.8600 - val_loss: 0.3180 - val_acc: 0.8780
# Epoch 43/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3555 - acc: 0.8660 - val_loss: 0.3733 - val_acc: 0.8670
# Epoch 44/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.4208 - acc: 0.8560 - val_loss: 0.2733 - val_acc: 0.8840
# Epoch 45/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3471 - acc: 0.8704 - val_loss: 0.4364 - val_acc: 0.8560
# Epoch 46/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3762 - acc: 0.8620 - val_loss: 0.4004 - val_acc: 0.8430
# Epoch 47/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3626 - acc: 0.8716 - val_loss: 0.4411 - val_acc: 0.8480
# Epoch 48/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3860 - acc: 0.8576 - val_loss: 0.3900 - val_acc: 0.8740
# Epoch 49/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3666 - acc: 0.8604 - val_loss: 0.2887 - val_acc: 0.8710
# Epoch 50/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3806 - acc: 0.8684 - val_loss: 0.3172 - val_acc: 0.8820
# Epoch 51/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.4207 - acc: 0.8668 - val_loss: 0.4908 - val_acc: 0.8750
# Epoch 52/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3421 - acc: 0.8716 - val_loss: 0.4625 - val_acc: 0.8530
# Epoch 53/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.4247 - acc: 0.8620 - val_loss: 0.3201 - val_acc: 0.8770
# Epoch 54/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3601 - acc: 0.8692 - val_loss: 0.3157 - val_acc: 0.8780
# Epoch 55/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3615 - acc: 0.8740 - val_loss: 0.4619 - val_acc: 0.8130
# Epoch 56/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3932 - acc: 0.8652 - val_loss: 0.4120 - val_acc: 0.8720
# Epoch 57/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3399 - acc: 0.8740 - val_loss: 0.3608 - val_acc: 0.8780
# Epoch 58/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3894 - acc: 0.8604 - val_loss: 0.3771 - val_acc: 0.8560
# Epoch 59/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3790 - acc: 0.8788 - val_loss: 0.4286 - val_acc: 0.8270
# Epoch 60/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3394 - acc: 0.8812 - val_loss: 0.3770 - val_acc: 0.8830
# Epoch 61/70
# 500/500 [==============================] - 64s 129ms/step - loss: 0.3377 - acc: 0.8792 - val_loss: 0.3011 - val_acc: 0.8770
# Epoch 62/70
# 500/500 [==============================] - 63s 127ms/step - loss: 0.3666 - acc: 0.8712 - val_loss: 0.3612 - val_acc: 0.8810
# Epoch 63/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3679 - acc: 0.8708 - val_loss: 0.4178 - val_acc: 0.8750
# Epoch 64/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3584 - acc: 0.8672 - val_loss: 0.4195 - val_acc: 0.8450
# Epoch 65/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3965 - acc: 0.8704 - val_loss: 0.3587 - val_acc: 0.8570
# Epoch 66/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3424 - acc: 0.8840 - val_loss: 0.3236 - val_acc: 0.8790
# Epoch 67/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3750 - acc: 0.8604 - val_loss: 0.3363 - val_acc: 0.8690
# Epoch 68/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3866 - acc: 0.8676 - val_loss: 0.3548 - val_acc: 0.8730
# Epoch 69/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3923 - acc: 0.8640 - val_loss: 0.4952 - val_acc: 0.8640
# Epoch 70/70
# 500/500 [==============================] - 63s 126ms/step - loss: 0.3634 - acc: 0.8732 - val_loss: 0.3366 - val_acc: 0.8770

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r-', label='Training acc')
plt.plot(epochs, val_acc, 'b-', label='Validation acc')
plt.xlabel("Epoch")
plt.ylabel("Training and Validation Accuracy")
plt.title('Accuracy Result')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'r-', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.xlabel("Epoch")
plt.ylabel("Training and Validation Loss")
plt.legend()
plt.show()

# %%
model.save("LBP_CNN_Ornek2_87.7.h5")

# %%
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# %%
test_path = './360lbp/'#test icin kullanilacak fotograflar

# %%
import itertools

def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
        test_path,
        target_size=(500, 500),
        batch_size=5,
        class_mode='categorical',
        shuffle=False)

class_labels = test_generator.class_indices
class_labels = {v: k for k, v in class_labels.items()}
classes = list(class_labels.values())


nb_validation_samples = 1435
batch_size = 5
#Confution Matrix and Classification Report
Y_pred = model.predict_generator(test_generator, nb_validation_samples // batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')
print(confusion_matrix(test_generator.classes, y_pred))
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# Found 1440 images belonging to 4 classes.
# Confusion Matrix
# [[307  23  28   2]
#  [  8 333  18   1]
#  [  5  30 322   3]
#  [  6  22  31 301]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.94      0.85      0.90       360
#           10       0.82      0.93      0.87       360
#           20       0.81      0.89      0.85       360
#           40       0.98      0.84      0.90       360
#
#     accuracy                           0.88      1440
#    macro avg       0.89      0.88      0.88      1440
# weighted avg       0.89      0.88      0.88      1440

# %%
import itertools

def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm = confusion_matrix(test_generator.classes, y_pred)
np.set_printoptions(precision=2)

# %%
plt.figure(figsize=(7,7))
plot_confusion_matrix(cm, classes=target_names,
                      title='Confusion matrix, without normalization')
# Out:
# [[307  23  28   2]
#  [  8 333  18   1]
#  [  5  30 322   3]
#  [  6  22  31 301]]

# %%
def plot_roc_curve(fpr,tpr):
    plt.plot(fpr,tpr)
    plt.axis([0,1,0,1]) 
    plt.xlabel('False Positive Rate') 
    plt.ylabel('True Positive Rate') 
    plt.show()

# %%
def perf_measure(y_actual, y_pred):
    class_id = set(y_actual).union(set(y_pred))
    TP = []
    FP = []
    TN = []
    FN = []

    for index ,_id in enumerate(class_id):
        TP.append(0)
        FP.append(0)
        TN.append(0)
        FN.append(0)
        for i in range(len(y_pred)):
            if y_actual[i] == y_pred[i] == _id:
                TP[index] += 1
            if y_pred[i] == _id and y_actual[i] != y_pred[i]:
                FP[index] += 1
            if y_actual[i] == y_pred[i] != _id:
                TN[index] += 1
            if y_pred[i] != _id and y_actual[i] != y_pred[i]:
                FN[index] += 1
               
    return class_id,TP, FP, TN, FN

# %%
print(perf_measure(test_generator.classes, y_pred))
# Out:
# ({0, 1, 2, 3}, [307, 333, 322, 301], [19, 75, 77, 6], [956, 930, 941, 962], [158, 102, 100, 171])

# %% [markdown]
# <h1 style="color:blue">For more information click to the link below : </h1>

# %% [markdown]
# <a href="https://ieeexplore.ieee.org/abstract/document/9254845" style="color:red"><B>Click Article</B></a>
