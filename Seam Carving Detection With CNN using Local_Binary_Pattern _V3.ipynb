# %% [markdown]
# ## Seam Carving Detection With CNN + Local_Binary_Pattern _V3

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from keras import layers
from keras import models
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = './train'
validation_dir = './validation'

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), strides=(1, 1), padding='same', input_shape=(500, 500, 3)))
model.add(layers.Activation('relu')) # this is just different syntax for specifying the activation function
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
#padding='valid'
model.add(layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

model.add(layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

model.add(layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))


model.add(layers.Conv2D(256, (3, 3), strides=(1, 1), padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))


model.add(layers.Flatten())
model.add(layers.Dropout(0.2))
model.add(layers.Dense(512))
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.1))
model.add(layers.Dense(4, activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer=optimizers.RMSprop(lr=1e-4),metrics=['acc'])#RMSprop(lr=1e-4)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\HamidullahTurkmen\.conda\envs\DeepLearning\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\HamidullahTurkmen\.conda\envs\DeepLearning\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 500, 500, 32)      896
# _________________________________________________________________
# activation_1 (Activation)    (None, 500, 500, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 250, 250, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 250, 250, 64)      18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 250, 250, 64)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 125, 125, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 125, 125, 64)      36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 125, 125, 64)      0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 62, 62, 128)       73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 62, 62, 128)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 31, 31, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 31, 31, 256)       295168
# _________________________________________________________________
# activation_5 (Activation)    (None, 31, 31, 256)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 57600)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 57600)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               29491712
# _________________________________________________________________
# activation_6 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 29,919,108
# Trainable params: 29,919,108
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_dir,
        # All images will be resized to 150x150
        target_size=(500, 500),
        #No. of images to be yielded from the generator per batch.
        batch_size=5,
        # Since we use binary_crossentropy loss, 
        #we need binary labels
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(500, 500),
        batch_size=5,
        class_mode='categorical')
# Out:
# Found 120000 images belonging to 4 classes.
# Found 40000 images belonging to 4 classes.

# %%
for data_batch, labels_batch in train_generator:
    print('data batch shape:', data_batch.shape)
    print('labels batch shape:', labels_batch.shape)
    break
# Out:
# data batch shape: (5, 500, 500, 3)
# labels batch shape: (5, 4)

# %%
import matplotlib.pyplot as plt
for data_batch, labels_batch in train_generator:
    print('data batch shape:', data_batch.shape)
    print('labels batch shape:', labels_batch.shape)
    plt.imshow(data_batch[0,:,:,:])       
    break
# Out:
# data batch shape: (5, 500, 500, 3)
# labels batch shape: (5, 4)

# %%
history = model.fit_generator(
      train_generator,
      steps_per_epoch=400,
      epochs=80,
      validation_data=validation_generator,
      validation_steps=150)
# Out:
# WARNING:tensorflow:From C:\Users\HamidullahTurkmen\.conda\envs\DeepLearning\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/80
# 400/400 [==============================] - 56s 139ms/step - loss: 1.3937 - acc: 0.2525 - val_loss: 1.3877 - val_acc: 0.2547
# Epoch 2/80
# 400/400 [==============================] - 50s 126ms/step - loss: 1.3903 - acc: 0.2620 - val_loss: 1.3855 - val_acc: 0.2827
# Epoch 3/80
# 400/400 [==============================] - 51s 127ms/step - loss: 1.3887 - acc: 0.2605 - val_loss: 1.3900 - val_acc: 0.2307
# Epoch 4/80
# 400/400 [==============================] - 51s 127ms/step - loss: 1.3540 - acc: 0.3165 - val_loss: 1.2206 - val_acc: 0.4440
# Epoch 5/80
# 400/400 [==============================] - 51s 128ms/step - loss: 1.0386 - acc: 0.5495 - val_loss: 0.6929 - val_acc: 0.6960
# Epoch 6/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.6273 - acc: 0.7590 - val_loss: 0.5179 - val_acc: 0.8027
# Epoch 7/80
# 400/400 [==============================] - 51s 128ms/step - loss: 0.5194 - acc: 0.8085 - val_loss: 0.5307 - val_acc: 0.7933
# Epoch 8/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.4938 - acc: 0.8190 - val_loss: 0.4548 - val_acc: 0.8173
# Epoch 9/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.4713 - acc: 0.8290 - val_loss: 0.4185 - val_acc: 0.8427
# Epoch 10/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.4636 - acc: 0.8330 - val_loss: 0.4704 - val_acc: 0.8013
# Epoch 11/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.4521 - acc: 0.8380 - val_loss: 0.4285 - val_acc: 0.8453
# Epoch 12/80
# 400/400 [==============================] - 51s 126ms/step - loss: 0.4073 - acc: 0.8350 - val_loss: 0.3950 - val_acc: 0.8440
# Epoch 13/80
# 400/400 [==============================] - 51s 128ms/step - loss: 0.4171 - acc: 0.8430 - val_loss: 0.3879 - val_acc: 0.8547
# Epoch 14/80
# 400/400 [==============================] - 51s 128ms/step - loss: 0.3937 - acc: 0.8435 - val_loss: 0.4543 - val_acc: 0.8333
# Epoch 15/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.3806 - acc: 0.8515 - val_loss: 0.3603 - val_acc: 0.8613
# Epoch 16/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.3745 - acc: 0.8550 - val_loss: 0.3836 - val_acc: 0.8547
# Epoch 17/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.3638 - acc: 0.8585 - val_loss: 0.3530 - val_acc: 0.8507
# Epoch 18/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.3385 - acc: 0.8640 - val_loss: 0.3794 - val_acc: 0.8560
# Epoch 19/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.3707 - acc: 0.8645 - val_loss: 0.3576 - val_acc: 0.8613
# Epoch 20/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.3594 - acc: 0.8550 - val_loss: 0.3798 - val_acc: 0.8373
# Epoch 21/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.3829 - acc: 0.8490 - val_loss: 0.3839 - val_acc: 0.8520
# Epoch 22/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.3349 - acc: 0.8770 - val_loss: 0.3599 - val_acc: 0.8573
# Epoch 23/80
# 400/400 [==============================] - 51s 128ms/step - loss: 0.3387 - acc: 0.8685 - val_loss: 0.3533 - val_acc: 0.8747
# Epoch 24/80
# 400/400 [==============================] - 50s 126ms/step - loss: 0.3725 - acc: 0.8605 - val_loss: 0.3520 - val_acc: 0.8587
# Epoch 25/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.4008 - acc: 0.8570 - val_loss: 0.5766 - val_acc: 0.7667
# Epoch 26/80
# 400/400 [==============================] - 51s 126ms/step - loss: 0.3500 - acc: 0.8755 - val_loss: 0.3040 - val_acc: 0.8893
# Epoch 27/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.3601 - acc: 0.8650 - val_loss: 0.3304 - val_acc: 0.8613
# Epoch 28/80
# 400/400 [==============================] - 51s 126ms/step - loss: 0.3601 - acc: 0.8685 - val_loss: 0.3131 - val_acc: 0.8773
# Epoch 29/80
# 400/400 [==============================] - 50s 126ms/step - loss: 0.3565 - acc: 0.8600 - val_loss: 0.3714 - val_acc: 0.8507
# Epoch 30/80
# 400/400 [==============================] - 50s 126ms/step - loss: 0.3641 - acc: 0.8640 - val_loss: 0.3534 - val_acc: 0.8613
# Epoch 31/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3558 - acc: 0.8620 - val_loss: 0.3055 - val_acc: 0.8560
# Epoch 32/80
# 400/400 [==============================] - 50s 126ms/step - loss: 0.3257 - acc: 0.8655 - val_loss: 0.2862 - val_acc: 0.8787
# Epoch 33/80
# 400/400 [==============================] - 52s 130ms/step - loss: 0.3331 - acc: 0.8740 - val_loss: 0.3115 - val_acc: 0.8787
# Epoch 34/80
# 400/400 [==============================] - 51s 128ms/step - loss: 0.3501 - acc: 0.8605 - val_loss: 0.3179 - val_acc: 0.8787
# Epoch 35/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.3691 - acc: 0.8645 - val_loss: 0.3721 - val_acc: 0.8893
# Epoch 36/80
# 400/400 [==============================] - 51s 128ms/step - loss: 0.3545 - acc: 0.8710 - val_loss: 0.3702 - val_acc: 0.8653
# Epoch 37/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.3514 - acc: 0.8670 - val_loss: 0.3779 - val_acc: 0.8680
# Epoch 38/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.3530 - acc: 0.8670 - val_loss: 0.3264 - val_acc: 0.8667
# Epoch 39/80
# 400/400 [==============================] - 51s 128ms/step - loss: 0.3379 - acc: 0.8795 - val_loss: 0.3796 - val_acc: 0.8773
# Epoch 40/80
# 400/400 [==============================] - 50s 126ms/step - loss: 0.3872 - acc: 0.8550 - val_loss: 0.3099 - val_acc: 0.8760
# Epoch 41/80
# 400/400 [==============================] - 51s 126ms/step - loss: 0.3667 - acc: 0.8670 - val_loss: 0.3093 - val_acc: 0.8600
# Epoch 42/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.3636 - acc: 0.8650 - val_loss: 0.3114 - val_acc: 0.8800
# Epoch 43/80
# 400/400 [==============================] - 51s 128ms/step - loss: 0.3878 - acc: 0.8555 - val_loss: 0.3335 - val_acc: 0.8747
# Epoch 44/80
# 400/400 [==============================] - 51s 127ms/step - loss: 0.3855 - acc: 0.8675 - val_loss: 0.3022 - val_acc: 0.8707
# Epoch 45/80
# 400/400 [==============================] - 50s 126ms/step - loss: 0.3475 - acc: 0.8715 - val_loss: 0.2887 - val_acc: 0.8933
# Epoch 46/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3771 - acc: 0.8700 - val_loss: 0.4119 - val_acc: 0.8520
# Epoch 47/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3254 - acc: 0.8855 - val_loss: 0.3551 - val_acc: 0.8773
# Epoch 48/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3453 - acc: 0.8695 - val_loss: 0.3228 - val_acc: 0.8867
# Epoch 49/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.4100 - acc: 0.8515 - val_loss: 0.4915 - val_acc: 0.8453
# Epoch 50/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3638 - acc: 0.8630 - val_loss: 0.3759 - val_acc: 0.8693
# Epoch 51/80
# 400/400 [==============================] - 51s 128ms/step - loss: 0.3688 - acc: 0.8685 - val_loss: 0.3412 - val_acc: 0.8853
# Epoch 52/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3749 - acc: 0.8700 - val_loss: 0.4206 - val_acc: 0.8707
# Epoch 53/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3458 - acc: 0.8745 - val_loss: 0.2739 - val_acc: 0.8920
# Epoch 54/80
# 400/400 [==============================] - 50s 124ms/step - loss: 0.3698 - acc: 0.8670 - val_loss: 0.3449 - val_acc: 0.8693
# Epoch 55/80
# 400/400 [==============================] - 50s 124ms/step - loss: 0.3823 - acc: 0.8690 - val_loss: 0.3404 - val_acc: 0.8773
# Epoch 56/80
# 400/400 [==============================] - 50s 124ms/step - loss: 0.3473 - acc: 0.8660 - val_loss: 0.3140 - val_acc: 0.8640
# Epoch 57/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3872 - acc: 0.8620 - val_loss: 0.3972 - val_acc: 0.8760
# Epoch 58/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3783 - acc: 0.8750 - val_loss: 0.8715 - val_acc: 0.8147
# Epoch 59/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3601 - acc: 0.8625 - val_loss: 0.3480 - val_acc: 0.8760
# Epoch 60/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3607 - acc: 0.8725 - val_loss: 0.2826 - val_acc: 0.8960
# Epoch 61/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.4098 - acc: 0.8545 - val_loss: 0.3331 - val_acc: 0.8693
# Epoch 62/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3502 - acc: 0.8735 - val_loss: 0.5190 - val_acc: 0.8627
# Epoch 63/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3665 - acc: 0.8700 - val_loss: 0.3082 - val_acc: 0.8827
# Epoch 64/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3283 - acc: 0.8780 - val_loss: 0.3797 - val_acc: 0.8480
# Epoch 65/80
# 400/400 [==============================] - 50s 124ms/step - loss: 0.3454 - acc: 0.8775 - val_loss: 0.3199 - val_acc: 0.8760
# Epoch 66/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.4098 - acc: 0.8680 - val_loss: 0.3766 - val_acc: 0.8733
# Epoch 67/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3298 - acc: 0.8770 - val_loss: 0.3223 - val_acc: 0.8613
# Epoch 68/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3713 - acc: 0.8695 - val_loss: 0.3705 - val_acc: 0.8733
# Epoch 69/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3889 - acc: 0.8480 - val_loss: 0.3337 - val_acc: 0.8707
# Epoch 70/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3810 - acc: 0.8555 - val_loss: 0.3238 - val_acc: 0.8747
# Epoch 71/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.4087 - acc: 0.8620 - val_loss: 0.3465 - val_acc: 0.8800
# Epoch 72/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3336 - acc: 0.8860 - val_loss: 0.3341 - val_acc: 0.8800
# Epoch 73/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3791 - acc: 0.8695 - val_loss: 0.4216 - val_acc: 0.8720
# Epoch 74/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3470 - acc: 0.8760 - val_loss: 0.3257 - val_acc: 0.8667
# Epoch 75/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3654 - acc: 0.8785 - val_loss: 0.6131 - val_acc: 0.8067
# Epoch 76/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3760 - acc: 0.8640 - val_loss: 0.3768 - val_acc: 0.8720
# Epoch 77/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3863 - acc: 0.8655 - val_loss: 0.4381 - val_acc: 0.8560
# Epoch 78/80
# 400/400 [==============================] - 50s 126ms/step - loss: 0.4200 - acc: 0.8565 - val_loss: 0.2778 - val_acc: 0.8920
# Epoch 79/80
# 400/400 [==============================] - 50s 126ms/step - loss: 0.3808 - acc: 0.8625 - val_loss: 0.5159 - val_acc: 0.8600
# Epoch 80/80
# 400/400 [==============================] - 50s 125ms/step - loss: 0.3795 - acc: 0.8770 - val_loss: 0.3615 - val_acc: 0.9040

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r-', label='Training acc')
plt.plot(epochs, val_acc, 'b-', label='Validation acc')
plt.xlabel("Epoch")
plt.ylabel("Training and Validation Accuracy")
plt.title('Accuracy Result')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'r-', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.xlabel("Epoch")
plt.ylabel("Training and Validation Loss")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# %%
test_path = './360lbp'

# %%
import itertools

def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# We need to recreate our validation generator with shuffle = false

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
        test_path,
        target_size=(500, 500),
        batch_size=5,
        class_mode='categorical',
        shuffle=False)

class_labels = test_generator.class_indices
class_labels = {v: k for k, v in class_labels.items()}
classes = list(class_labels.values())


nb_validation_samples = 1435
batch_size = 5
#Confution Matrix and Classification Report
Y_pred = model.predict_generator(test_generator, nb_validation_samples // batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)

#print('Confusion Matrix')
#print(confusion_matrix(test_generator.classes, y_pred))
print("\n\n")
print('Classification Report\n')
target_names = list(class_labels.values())
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# Found 1440 images belonging to 4 classes.
#
#
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.90       360
#           10       0.90      0.89      0.90       360
#           20       0.85      0.90      0.87       360
#           40       0.85      0.91      0.88       360
#
#     accuracy                           0.89      1440
#    macro avg       0.89      0.89      0.89      1440
# weighted avg       0.89      0.89      0.89      1440

# %%
import itertools

def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm = confusion_matrix(test_generator.classes, y_pred)
np.set_printoptions(precision=2)

# %%
plt.figure(figsize=(7,7))
plot_confusion_matrix(cm, classes=target_names,
                      title='Confusion matrix, without normalization')
# Out:
# [[305  16  19  20]
#  [  6 320  15  19]
#  [  4  11 325  20]
#  [  1   7  25 327]]

# %%
def plot_roc_curve(fpr,tpr):
    plt.plot(fpr,tpr)
    plt.axis([0,1,0,1]) 
    plt.xlabel('False Positive Rate') 
    plt.ylabel('True Positive Rate') 
    plt.show()

# %%
def perf_measure(y_actual, y_pred):
    class_id = set(y_actual).union(set(y_pred))
    TP = []
    FP = []
    TN = []
    FN = []

    for index ,_id in enumerate(class_id):
        TP.append(0)
        FP.append(0)
        TN.append(0)
        FN.append(0)
        for i in range(len(y_pred)):
            if y_actual[i] == y_pred[i] == _id:
                TP[index] += 1
            if y_pred[i] == _id and y_actual[i] != y_pred[i]:
                FP[index] += 1
            if y_actual[i] == y_pred[i] != _id:
                TN[index] += 1
            if y_pred[i] != _id and y_actual[i] != y_pred[i]:
                FN[index] += 1
               
    return class_id,TP, FP, TN, FN

# %%
print(perf_measure(test_generator.classes, y_pred))
# Out:
# ({0, 1, 2, 3}, [305, 320, 325, 327], [11, 34, 59, 59], [972, 957, 952, 950], [152, 129, 104, 104])

# %%
model.save("Seam Carving Detection With CNN + Local_Binary_Pattern _V3.h5")

# %% [markdown]
# <h1 style="color:blue">For more information click to the link below : </h1>

# %% [markdown]
# <a href="https://ieeexplore.ieee.org/abstract/document/9254845" style="color:red"><B>Click Article</B></a>
